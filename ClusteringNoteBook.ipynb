# %% [markdown]
# <a href="https://colab.research.google.com/github/pkanyu/Colab-Notebooks/blob/main/ClusteringNoteBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clustering: Unsupervised Machine Learning where the GOAL is to determine hidden clusters(groups) within the dataset.
# Step1: Read Data
import pandas
data = pandas.read_csv("https://modcom.co.ke/data/datasets/AirlinesCluster.csv")
data
# Out:
#       Balance  QualMiles  BonusMiles  BonusTrans  FlightMiles  FlightTrans  \
# 0       28143          0         174           1            0            0
# 1       19244          0         215           2            0            0
# 2       41354          0        4123           4            0            0
# 3       14776          0         500           1            0            0
# 4       97752          0       43300          26         2077            4
# ...       ...        ...         ...         ...          ...          ...
# 3994    18476          0        8525           4          200            1
# 3995    64385          0         981           5            0            0
# 3996    73597          0       25447           8            0            0
# 3997    54899          0         500           1          500            1
# 3998     3016          0           0           0            0            0
#
#       DaysSinceEnroll
# 0                7000
# 1                6968
# 2                7034
# 3                6952
# 4                6935
# ...               ...
# 3994             1403
# 3995             1395
# 3996             1402
# 3997             1401
# 3998             1398
#
# [3999 rows x 7 columns]

# %%
# Grouping Data into Different Clusters based on Similarities
# E,g Safaricom by grouping their customers based on calls,sms,bundles
array = data.values
dataValues =array[:,4:7]
data = pandas.DataFrame(dataValues,columns = ["FlightMiles", 	"FlightTrans"," 	DaysSinceEnroll"])
data
# Out:
#       FlightMiles  FlightTrans   \tDaysSinceEnroll
# 0               0            0                7000
# 1               0            0                6968
# 2               0            0                7034
# 3               0            0                6952
# 4            2077            4                6935
# ...           ...          ...                 ...
# 3994          200            1                1403
# 3995            0            0                1395
# 3996            0            0                1402
# 3997          500            1                1401
# 3998            0            0                1398
#
# [3999 rows x 3 columns]

# %%
# Split Data into x
array = data.values
X = array[ :,:]

# %%
# Import KMeans(Group data based on the mean)
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5,random_state=42)
clusters = model.fit(X)
clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d8d8c3d0300a> in <cell line: 4>()
#       2 from sklearn.cluster import KMeans
#       3 model = KMeans(n_clusters=5,random_state=42)
# ----> 4 clusters = model.fit(X)
#       5 clusters
#
# NameError: name 'X' is not defined

# %%
# Mean Clusters(centronoids)
means = model.cluster_centers_
groups = pandas.DataFrames(means, columns = ["FlightMiles", 	"FlightTrans"," 	DaysSinceEnroll"])
groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-155b75ce1a76> in <cell line: 2>()
#       1 # Mean Clusters(centronoids)
# ----> 2 means = model.cluster_centers_
#       3 groups = pandas.DataFrames(means, columns = ["FlightMiles",     "FlightTrans","         DaysSinceEnroll"])
#       4 groups
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %%
data["cluster"] = models.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e457b43a0ba6> in <cell line: 1>()
# ----> 1 data["cluster"] = models.labels_
#
# NameError: name 'models' is not defined

# %%
# Getting Members of the Same Clusters
# E,g Cluster 4 Members
cluster_4_members = data[data["cluster"] == 4]
cluster_4_members
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-dec308be7556> in <cell line: 3>()
#       1 # Getting Members of the Same Clusters
#       2 # E,g Cluster 4 Members
# ----> 3 cluster_4_members = data[data["cluster"] == 4]
#       4 cluster_4_members
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'cluster'

# %%
cluster_4_members.to_cs("Cluster4.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a9aad311700c> in <cell line: 1>()
# ----> 1 cluster_4_members.to_cs("Cluster4.csv")
#
# NameError: name 'cluster_4_members' is not defined
