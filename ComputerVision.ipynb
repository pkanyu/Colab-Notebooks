# %% [markdown]
# <a href="https://colab.research.google.com/github/pkanyu/Colab-Notebooks/blob/main/ComputerVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Load the data
train_dir = '/home/feelgood/Downloads/CovidTest/Dataset_A/train/'
validate_dir = '/home/feelgood/Downloads/CovidTest/Dataset_A/validation/'
train_covid_dir = os.path.join(train_dir, 'Covid')
train_normal_dir = os.path.join(train_dir, 'Normal')
validate_covid_dir = os.path.join(validate_dir, 'Covid')
validate_normal_dir = os.path.join(validate_dir, 'Normal')

# Get the image paths and labels
train_covid_paths = [os.path.join(train_covid_dir, filename) for filename in os.listdir(train_covid_dir)]
train_normal_paths = [os.path.join(train_normal_dir, filename) for filename in os.listdir(train_normal_dir)]
validate_covid_paths = [os.path.join(validate_covid_dir, filename) for filename in os.listdir(validate_covid_dir)]
validate_normal_paths = [os.path.join(validate_normal_dir, filename) for filename in os.listdir(validate_normal_dir)]

# Create the dataframes
train_df = pd.DataFrame({'image_path': train_covid_paths + train_normal_paths, 'label': ['covid'] * len(train_covid_paths) + ['normal'] * len(train_normal_paths)})
validate_df = pd.DataFrame({'image_path': validate_covid_paths + validate_normal_paths, 'label': ['covid'] * len(validate_covid_paths) + ['normal'] * len(validate_normal_paths)})

# Read and preprocess the images
def read_and_preprocess_image(image_path):
    image = cv2.imread(image_path)
    # Add any preprocessing steps here if needed
    return image

train_images = np.array([read_and_preprocess_image(path) for path in X_train])
validate_images = np.array([read_and_preprocess_image(path) for path in X_test])

# Flatten the images for Logistic Regression
X_train_flat = train_images.reshape(train_images.shape[0], -1)
X_test_flat = validate_images.reshape(validate_images.shape[0], -1)

# Train the model
model = LogisticRegression()
model.fit(X_train_flat, y_train)

# Evaluate the model
y_pred = model.predict(X_test_flat)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

# Generate a confusion matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-deb5a3b72e59> in <cell line: 20>()
#      18
#      19 # Get the image paths and labels
# ---> 20 train_covid_paths = [os.path.join(train_covid_dir, filename) for filename in os.listdir(train_covid_dir)]
#      21 train_normal_paths = [os.path.join(train_normal_dir, filename) for filename in os.listdir(train_normal_dir)]
#      22 validate_covid_paths = [os.path.join(validate_covid_dir, filename) for filename in os.listdir(validate_covid_dir)]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/feelgood/Downloads/CovidTest/Dataset_A/train/Covid'

# %%
print(os.path.exists('/home/feelgood/Downloads/CovidTest/Dataset_A/train/covid'))
print(os.path.exists('/home/feelgood/Downloads/CovidTest/Dataset_A/train'))
# Out:
# False
# False

# %%
# prompt: I want to upload the folders with the images to google colab.The files are stored locally in my computer

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-01f2cc70-6015-47b1-8cd2-e641e0aa9446" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01f2cc70-6015-47b1-8cd2-e641e0aa9446">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: Now here, I want to pass an image and print out if the person has covid or not


def predict_covid(image_path):
  # Load the image
  image = plt.imread(image_path)

  # Preprocess the image
  image = scaler.transform(image.reshape(1, -1))

  # Predict the label
  prediction = model.predict(image)

  # Return the prediction
  return prediction

# Get the image path from the user
image_path = input('Enter the image path: ')

# Predict the label
prediction = predict_covid(image_path)

# Print the prediction
print('Prediction:', prediction)
